# %% [markdown]
# ---
# Material for the course "Introducción a la inteligencia artificial"
#
# The following notes written by SERGIO G RODRIGO (2023-2024)</font>
#
# ---
# # **Tensorflow-Keras applications with a focus on physics and mathematics**
# +  horas por topic = 12 clases 6 semanas
# 1. Simple example of regression with dense layers (ahora está con API...cambiar o dar las dos formas o 3 formas a lo Geron)
# 2. My numerical method is low! Can neural networks help me?: Neural Network based optical scattering prediction in nanophotonics(**HECHO**)
# 3. Classifying digits: a first step for more impressive problems!
# 4. Magnetism, images and neural networks: 2D Ising model. (**HECHO**)
# 5. Recurrent Neural Networks (ejemplo simple Geron) ??
# 6. [Going deeper into Tensorflow-Keras: solving Ordinary Differential Equations with neural-networks.](https://github.com/IrisFDTD/PINNs-for-education/tree/v1.0)
# 7. [Bonus track: symmetries in physics managed with neural networks (preguntar a Luis qué le parece que de la(s) clase Pablo)](https://github.com/pablocalvo7/Symmetry_Seeker_NN)
